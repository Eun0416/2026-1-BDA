# %% [markdown]
# <a href="https://colab.research.google.com/github/Eun0416/2026-1-BDA/blob/main/code/pandas_cookbook_ko.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # pandas Cookbook 한글 문서
#
# 이 노트북은 pandas 공식 사용자 가이드의 Cookbook 페이지를 바탕으로, 설명은 한글로 정리하고 코드 예시는 원문의 형태를 최대한 유지해 재구성한 자료입니다.
#
# - 원문: pandas User Guide - Cookbook
# - 목표: 자주 쓰는 패턴을 한국어 설명과 함께 빠르게 학습
# - 원칙: 설명은 한글, 코드는 그대로 또는 실행 가능한 형태로 유지
#
# 출처: https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook

# %% [markdown]
# Cookbook 페이지는 pandas에서 자주 마주치는 작업을 짧고 실용적인 예제로 모아둔 레시피 모음입니다. 원문도 'short and sweet' 예제를 지향하며, pandas와 NumPy를 중심으로 실제 데이터 처리 패턴을 빠르게 익히도록 구성되어 있습니다.
#
# 이 노트북은 원문의 큰 흐름을 따라 다음 주제를 정리합니다.
# - Idioms: 조건 처리, 분할, 조건식 만들기
# - Selection: 행/열 선택, 새 열 만들기
# - MultiIndexing: 계층형 인덱스 다루기
# - Missing data / Grouping / Pivot / Apply
# - Timeseries / Merge / IO / Computation / Timedelta
# - 예제 데이터 생성과 상수 시리즈 판별

# %% [markdown]
# ## Selection
#
# 이 절은 DataFrame에서 조건 기반 선택, loc/iloc 슬라이싱, 보조 열 생성 같은 기본 조작을 다룹니다. pandas 사용 빈도가 매우 높은 영역입니다.

# %% [markdown]
# ## MultiIndexing
#
# 이 절은 행 또는 열에 계층형 인덱스를 부여해 다차원 구조처럼 다루는 방법을 보여줍니다. 복잡한 표 구조를 정리하거나 부분 선택할 때 매우 유용합니다.

# %% [markdown]
# ## Missing data
#
# 결측값을 채우는 간단한 패턴을 소개합니다. 시계열에서 앞/뒤 값으로 결측을 메우는 작업은 매우 흔합니다.

# %% [markdown]
# ## Grouping
#
# groupby는 pandas의 핵심 기능 중 하나입니다. 그룹별 집계뿐 아니라 apply, transform, shift, resample과 결합해 복잡한 분석도 처리할 수 있습니다.

# %% [markdown]
# ## Pivot
#
# pivot_table은 범주형 데이터를 요약표 형태로 재구성할 때 사용합니다. 연도-월 교차표, 지역-도시 매출 요약 같은 문제에 적합합니다.

# %% [markdown]
# ## Apply
#
# apply는 유연하지만 남용하면 느릴 수 있습니다. 그래도 리스트 확장, 복합 계산, rolling window 커스텀 계산 같은 경우에는 유용합니다.

# %% [markdown]
# ## 기타 주제
#
# Cookbook에는 시계열, 병합, 파일 입출력, 상관계수 계산, timedelta 연산 등 실무형 예제가 넓게 포함되어 있습니다. 이 노트북에서는 대표 패턴 위주로 예시를 담았습니다.

# %% [markdown]
# ---
# ### 시작

# %% [markdown]
# ## Idioms
#
# 이 절은 pandas에서 자주 쓰는 '관용적 표현'을 보여줍니다. 특히 조건에 따라 값을 바꾸거나, 데이터를 나누거나, 복합 조건을 만드는 패턴이 핵심입니다.

# %% [markdown]
# ### 기본 예제 DataFrame
#
# 이후 여러 예제에서 반복해서 사용하는 간단한 DataFrame입니다.

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(
    {"AAA": [4, 5, 6, 7], "BBB": [10, 20, 30, 40], "CCC": [100, 50, -30, -50]}
)
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %% [markdown]
# ### If-then
#
# 특정 조건을 만족하는 행만 골라 값을 바꾸려면 `loc`를 사용합니다. 한 열만 바꿀 수도 있고 여러 열을 동시에 바꿀 수도 있습니다.

# %%
df.loc[df.AAA >= 5]
# Out:
#    AAA  BBB  CCC
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
df.loc[df.AAA >= 5, "BBB"] = -1
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   -1   50
# 2    6   -1  -30
# 3    7   -1  -50

# %%
df.loc[df.AAA >= 5, ["BBB", "CCC"]] = 555
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5  555  555
# 2    6  555  555
# 3    7  555  555

# %%
df.loc[df.AAA < 5, ["BBB", "CCC"]] = 2000
df
# Out:
#    AAA   BBB   CCC
# 0    4  2000  2000
# 1    5   555   555
# 2    6   555   555
# 3    7   555   555

# %% [markdown]
# ### df.where와 np.where
#
# 불리언 마스크를 따로 만든 뒤 `where`를 쓰면 '조건을 만족하면 유지, 아니면 다른 값 대체' 형태를 표현할 수 있습니다. `np.where`는 새 범주형 열을 만들 때 자주 사용합니다.

# %%
from IPython.display import display_html
def display_side_by_side(*args):
    """여러 데이터프레임 비교가 쉽게 옆쪽으로 표시한다"""
    html_str=''
    for df in args:
        html_str += df.to_html() + '&nbsp;'*4
    display_html(html_str.replace('table','table style="display:inline"'), raw=True)

# %%
df_mask = pd.DataFrame(
    {"AAA": [True] * 4, "BBB": [False] * 4, "CCC": [True, False] * 2}
)
df_mask
# Out:
#     AAA    BBB    CCC
# 0  True  False   True
# 1  True  False  False
# 2  True  False   True
# 3  True  False  False

# %%
df = pd.DataFrame(
    {"AAA": [4, 5, 6, 7], "BBB": [10, 20, 30, 40], "CCC": [100, 50, -30, -50]}
)
display_side_by_side(df, df_mask)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AAA</th>
#       <th>BBB</th>
#       <th>CCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4</td>
#       <td>10</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>20</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>6</td>
#       <td>30</td>
#       <td>-30</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>7</td>
#       <td>40</td>
#       <td>-50</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AAA</th>
#       <th>BBB</th>
#       <th>CCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>True</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>True</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>True</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>True</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;

# %%
df.where(df_mask, -1000) # True: 원값을 유지, False: -1000으로 대체
# Out:
#    AAA   BBB   CCC
# 0    4 -1000   100
# 1    5 -1000 -1000
# 2    6 -1000   -30
# 3    7 -1000 -1000

# %%
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
df = pd.DataFrame(
    {"AAA": [4, 5, 6, 7], "BBB": [10, 20, 30, 40], "CCC": [100, 50, -30, -50]}
)
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
df["logic"] = np.where(df["AAA"] > 5, "high", "low")
df
# Out:
#    AAA  BBB  CCC logic
# 0    4   10  100   low
# 1    5   20   50   low
# 2    6   30  -30  high
# 3    7   40  -50  high

# %% [markdown]
# - np.where()와 df.where() 비교
#
# | 함수       | 구조                  | 의미          |
# | -------- | ------------------- | ----------- |
# | np.where | (조건, True값, False값) | 완전한 if-else |
# | df.where | (조건, False대체값)      | True 유지     |

# %% [markdown]
# ### Splitting
#
# 조건식으로 DataFrame을 둘로 나누는 가장 단순한 방법입니다.

# %%
df = pd.DataFrame(
    {"AAA": [4, 5, 6, 7], "BBB": [10, 20, 30, 40], "CCC": [100, 50, -30, -50]}
)
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
df[df.AAA <= 5]
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50

# %%
low_df = df[df.AAA <= 5]
high_df = df[df.AAA > 5]
display_side_by_side(low_df, high_df)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AAA</th>
#       <th>BBB</th>
#       <th>CCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4</td>
#       <td>10</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>20</td>
#       <td>50</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AAA</th>
#       <th>BBB</th>
#       <th>CCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>6</td>
#       <td>30</td>
#       <td>-30</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>7</td>
#       <td>40</td>
#       <td>-50</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;

# %% [markdown]
# ### 복합 조건 만들기
#
# `&`, `|`, `~`를 사용해 조건을 조합할 수 있습니다. 괄호를 각 조건에 명확히 씌우는 것이 중요합니다.

# %%
df = pd.DataFrame(
    {"AAA": [4, 5, 6, 7], "BBB": [10, 20, 30, 40], "CCC": [100, 50, -30, -50]}
)
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
df.loc[(df["BBB"] < 25) & (df["CCC"] >= -40), "AAA"] # 결과는 한 열이므로 Series
# Out:
# 0    4
# 1    5
# Name: AAA, dtype: int64

# %%
df.loc[(df["BBB"] > 25) | (df["CCC"] >= 75), "AAA"] = 999
df
# Out:
#    AAA  BBB  CCC
# 0  999   10  100
# 1    5   20   50
# 2  999   30  -30
# 3  999   40  -50

# %% [markdown]
# ### argsort()의 핵심 개념
# “정렬된 값”이 아니라 “정렬 순서”를 반환
# np.argsort(a)는 배열을 정렬하는 인덱스 배열을 반환

# %%
a = np.array([10, 1, 5, 3])
a.argsort() # 정렬된 인덱스를 반환
# Out:
# array([1, 3, 2, 0])

# %%
a[a.argsort()]
# Out:
# array([ 1,  3,  5, 10])

# %%
df = pd.DataFrame(
    {"AAA": [4, 5, 6, 7], "BBB": [10, 20, 30, 40], "CCC": [100, 50, -30, -50]}
)
aValue = 43.0
(df.CCC - aValue).abs()
# Out:
# 0    57.0
# 1     7.0
# 2    73.0
# 3    93.0
# Name: CCC, dtype: float64

# %%
(df.CCC - aValue).abs().argsort()
# Out:
# 0    1
# 1    0
# 2    2
# 3    3
# Name: CCC, dtype: int64

# %%
df.loc[(df.CCC - aValue).abs().argsort()]
# Out:
#    AAA  BBB  CCC
# 1    5   20   50
# 0    4   10  100
# 2    6   30  -30
# 3    7   40  -50

# %% [markdown]
# ### 동적으로 조건 합치기
#
# 조건이 여러 개이고 상황에 따라 개수가 바뀐다면 리스트에 모은 뒤 `functools.reduce`로 결합할 수 있습니다.

# %%
df = pd.DataFrame(
    {"AAA": [4, 5, 6, 7], "BBB": [10, 20, 30, 40], "CCC": [100, 50, -30, -50]}
)
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
Crit1 = df.AAA <= 5.5
Crit2 = df.BBB == 10.0
Crit3 = df.CCC > -40.0

CritList = [Crit1, Crit2, Crit3]
CritList
# Out:
# [0     True
#  1     True
#  2    False
#  3    False
#  Name: AAA, dtype: bool,
#  0     True
#  1    False
#  2    False
#  3    False
#  Name: BBB, dtype: bool,
#  0     True
#  1     True
#  2     True
#  3    False
#  Name: CCC, dtype: bool]

# %% [markdown]
# ### Python functools.reduce() 함수 설명
# - reduce()는 여러 값을 하나의 결과로 “누적 축소(reduce)”하는 함수이다
# - 리스트의 요소를 앞에서부터 두 개씩 결합하며 반복 연산한다
# - 함수는 반드시 두 개의 인자를 받는 형태여야 한다
# - 합계, 곱, 최대값, 조건 결합 등 다양한 누적 계산에 활용된다

# %%
import functools

AllCrit = functools.reduce(lambda x, y: x & y, CritList)
df[AllCrit]
# Out:
#    AAA  BBB  CCC
# 0    4   10  100

# %%
from functools import reduce

reduce(lambda x, y: x + y, [1, 2, 3, 4])
# Out:
# 10

# %% [markdown]
# ## 데이터프레임 선택

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(
    {"AAA": [4, 5, 6, 7], "BBB": [10, 20, 30, 40], "CCC": [100, 50, -30, -50]}
)
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
df[(df.AAA <= 6) & (df.index.isin([0, 2, 4]))]
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 2    6   30  -30

# %%
df2 = df[(df.AAA <= 6) & (df.index.isin([0, 2, 4]))]
display_side_by_side(df, df2)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AAA</th>
#       <th>BBB</th>
#       <th>CCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4</td>
#       <td>10</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>20</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>6</td>
#       <td>30</td>
#       <td>-30</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>7</td>
#       <td>40</td>
#       <td>-50</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AAA</th>
#       <th>BBB</th>
#       <th>CCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4</td>
#       <td>10</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>6</td>
#       <td>30</td>
#       <td>-30</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;

# %% [markdown]
# ### loc와 iloc
#
# `loc`는 라벨 기준, `iloc`는 위치 기준 선택입니다. 정수 인덱스를 사용할 때 둘의 차이를 분명히 이해해야 합니다.

# %%
df = pd.DataFrame(
    {"AAA": [4, 5, 6, 7], "BBB": [10, 20, 30, 40], "CCC": [100, 50, -30, -50]},
    index=["foo", "bar", "boo", "kar"],
)
df
# Out:
#      AAA  BBB  CCC
# foo    4   10  100
# bar    5   20   50
# boo    6   30  -30
# kar    7   40  -50

# %%
df.loc["bar":"kar"]
# Out:
#      AAA  BBB  CCC
# bar    5   20   50
# boo    6   30  -30
# kar    7   40  -50

# %%
df[0:3]
# Out:
#      AAA  BBB  CCC
# foo    4   10  100
# bar    5   20   50
# boo    6   30  -30

# %%
df["bar":"kar"]
# Out:
#      AAA  BBB  CCC
# bar    5   20   50
# boo    6   30  -30
# kar    7   40  -50

# %%
data = {"AAA": [4, 5, 6, 7], "BBB": [10, 20, 30, 40], "CCC": [100, 50, -30, -50]}
df2 = pd.DataFrame(data=data, index=[1, 2, 3, 4])  # Note index starts at 1.
df2
# Out:
#    AAA  BBB  CCC
# 1    4   10  100
# 2    5   20   50
# 3    6   30  -30
# 4    7   40  -50

# %%
df2.iloc[1:3]  # Position-oriented
# Out:
#    AAA  BBB  CCC
# 2    5   20   50
# 3    6   30  -30

# %%
df2.loc[1:3]
# Out:
#    AAA  BBB  CCC
# 1    4   10  100
# 2    5   20   50
# 3    6   30  -30

# %%
df2
# Out:
#    AAA  BBB  CCC
# 1    4   10  100
# 2    5   20   50
# 3    6   30  -30
# 4    7   40  -50

# %%
df2[1:3]
# Out:
#    AAA  BBB  CCC
# 2    5   20   50
# 3    6   30  -30

# %%
df2
# Out:
#    AAA  BBB  CCC
# 1    4   10  100
# 2    5   20   50
# 3    6   30  -30
# 4    7   40  -50

# %% [markdown]
# 명시적인 슬라이싱 방법은 두 가지가 있으며, 일반적인 경우로 세 번째 방법이 있습니다.
# - 위치 기반 (파이썬 슬라이싱 스타일: 끝 제외)
# - 레이블 중심 (비 파이썬 슬라이싱 스타일: 끝 포함)
# - 일반 (슬라이스 스타일: 슬라이스에 레이블 또는 위치 정보가 포함되어 있는지 여부에 따라 다름)

# %%
iloc_result = df2.iloc[1:3]
loc_result = df2.loc[1:3]

display_side_by_side(iloc_result, loc_result)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AAA</th>
#       <th>BBB</th>
#       <th>CCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#       <td>20</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6</td>
#       <td>30</td>
#       <td>-30</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AAA</th>
#       <th>BBB</th>
#       <th>CCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>10</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#       <td>20</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6</td>
#       <td>30</td>
#       <td>-30</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;

# %%
df = pd.DataFrame(
    {"AAA": [4, 5, 6, 7], "BBB": [10, 20, 30, 40], "CCC": [100, 50, -30, -50]}
)
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
df[~((df.AAA <= 6) & (df.index.isin([0, 2, 4])))]
# Out:
#    AAA  BBB  CCC
# 1    5   20   50
# 3    7   40  -50

# %%
df[((df.AAA <= 6) & (df.index.isin([0, 2, 4])))]
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 2    6   30  -30

# %% [markdown]
# ### 새 열 만들기
#
# 기존 숫자 열을 범주형 설명 열로 바꾸거나, 그룹별 최소값 행을 찾는 패턴입니다.

# %%
df = pd.DataFrame({"AAA": [1, 2, 1, 3], "BBB": [1, 1, 2, 2], "CCC": [2, 1, 3, 1]})
df
# Out:
#    AAA  BBB  CCC
# 0    1    1    2
# 1    2    1    1
# 2    1    2    3
# 3    3    2    1

# %%
source_cols = df.columns
new_cols = [str(x) + "_cat" for x in source_cols]
new_cols
# Out:
# ['AAA_cat', 'BBB_cat', 'CCC_cat']

# %%
categories = {1: "Alpha", 2: "Beta", 3: "Charlie"}
print(categories.get(df.iat[0, 0]))
print(categories.get(4))
# Out:
# Alpha
# None

# %%
df[source_cols].map(categories.get)
# Out:
#        AAA    BBB      CCC
# 0    Alpha  Alpha     Beta
# 1     Beta  Alpha    Alpha
# 2    Alpha   Beta  Charlie
# 3  Charlie   Beta    Alpha

# %%
categories = {1: "Alpha", 2: "Beta", 3: "Charlie"}

df[new_cols] = df[source_cols].map(categories.get)
df
# Out:
#    AAA  BBB  CCC  AAA_cat BBB_cat  CCC_cat
# 0    1    1    2    Alpha   Alpha     Beta
# 1    2    1    1     Beta   Alpha    Alpha
# 2    1    2    3    Alpha    Beta  Charlie
# 3    3    2    1  Charlie    Beta    Alpha

# %%
df = pd.DataFrame(
    {"AAA": [1, 1, 1, 2, 2, 2, 3, 3], "BBB": [2, 1, 3, 4, 5, 1, 2, 3]}
)
df
# Out:
#    AAA  BBB
# 0    1    2
# 1    1    1
# 2    1    3
# 3    2    4
# 4    2    5
# 5    2    1
# 6    3    2
# 7    3    3

# %%
df.groupby("AAA")["BBB"]

# %%
# 각 그룹에 속한 행 인덱스 목록
df.groupby("AAA")["BBB"].groups
# Out:
# {1: [0, 1, 2], 2: [3, 4, 5], 3: [6, 7]}

# %%
df.groupby("AAA")["BBB"].get_group(1)
# Out:
# 0    2
# 1    1
# 2    3
# Name: BBB, dtype: int64

# %%
df.groupby("AAA")["BBB"].get_group(2)
# Out:
# 3    4
# 4    5
# 5    1
# Name: BBB, dtype: int64

# %%
df.groupby("AAA")["BBB"].get_group(3)
# Out:
# 6    2
# 7    3
# Name: BBB, dtype: int64

# %% [markdown]
# 방법 1: idxmin() 함수를 사용하여 최솟값의 인덱스를 얻습니다.

# %%
df.groupby("AAA")["BBB"].idxmin()
# Out:
# AAA
# 1    1
# 2    5
# 3    6
# Name: BBB, dtype: int64

# %%
df.loc[df.groupby("AAA")["BBB"].idxmin()]
# Out:
#    AAA  BBB
# 1    1    1
# 5    2    1
# 6    3    2

# %% [markdown]
# 방법 2: 정렬한 다음 각 항목에서 첫 번째 항목을 가져옵니다.

# %%
df
# Out:
#    AAA  BBB
# 0    1    2
# 1    1    1
# 2    1    3
# 3    2    4
# 4    2    5
# 5    2    1
# 6    3    2
# 7    3    3

# %%
df.sort_values(by="BBB")
# Out:
#    AAA  BBB
# 1    1    1
# 5    2    1
# 6    3    2
# 0    1    2
# 7    3    3
# 2    1    3
# 3    2    4
# 4    2    5

# %%
df.sort_values(by="BBB").groupby("AAA", as_index=False).first()
# Out:
#    AAA  BBB
# 0    1    1
# 1    2    1
# 2    3    2

# %%
df.sort_values(by="BBB").groupby("AAA", as_index=False)

# %%
df.sort_values(by="BBB").groupby("AAA", as_index=False).groups
# Out:
# {1: [1, 0, 2], 2: [5, 3, 4], 3: [6, 7]}

# %% [markdown]
# ### MultiIndex 기초
#
# 열 이름에 포함된 접두어를 분리해 계층형 열 인덱스로 바꾼 뒤, stack과 reset_index로 형태를 재구성할 수 있습니다.

# %%
df = pd.DataFrame(
    {
        "row": [0, 1, 2],
        "One_X": [1.1, 1.1, 1.1],
        "One_Y": [1.2, 1.2, 1.2],
        "Two_X": [1.11, 1.11, 1.11],
        "Two_Y": [1.22, 1.22, 1.22],
    }
)
df
# Out:
#    row  One_X  One_Y  Two_X  Two_Y
# 0    0    1.1    1.2   1.11   1.22
# 1    1    1.1    1.2   1.11   1.22
# 2    2    1.1    1.2   1.11   1.22

# %%
# 지정한 열을 행 index로 지정
df = df.set_index("row")
df
# Out:
#      One_X  One_Y  Two_X  Two_Y
# row
# 0      1.1    1.2   1.11   1.22
# 1      1.1    1.2   1.11   1.22
# 2      1.1    1.2   1.11   1.22

# %%
df.index
# Out:
# Index([0, 1, 2], dtype='int64', name='row')

# %%
[tuple(c.split("_")) for c in df.columns]
# Out:
# [('One', 'X'), ('One', 'Y'), ('Two', 'X'), ('Two', 'Y')]

# %%
df.columns = pd.MultiIndex.from_tuples([tuple(c.split("_")) for c in df.columns])
df.columns
# Out:
# MultiIndex([('One', 'X'),
#             ('One', 'Y'),
#             ('Two', 'X'),
#             ('Two', 'Y')],
#            )

# %%
df
# Out:
#      One        Two
#        X    Y     X     Y
# row
# 0    1.1  1.2  1.11  1.22
# 1    1.1  1.2  1.11  1.22
# 2    1.1  1.2  1.11  1.22

# %% [markdown]
# ### df.stack(0)의 동작 방식
# - 원래 구조:
#     - 행 인덱스 (index)
#     - 열 (columns, possibly MultiIndex)
# - 변환 후 구조:
#     - 선택된 열 레벨이 행 인덱스로 이동
#     - 결과적으로 행 인덱스가 증가하고 열 수는 감소

# %%
display_side_by_side(df, df.stack(0))
# Out:
# /tmp/ipykernel_1364/3764189130.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   display_side_by_side(df, df.stack(0))
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="2" halign="left">One</th>
#       <th colspan="2" halign="left">Two</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>X</th>
#       <th>Y</th>
#       <th>X</th>
#       <th>Y</th>
#     </tr>
#     <tr>
#       <th>row</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.1</td>
#       <td>1.2</td>
#       <td>1.11</td>
#       <td>1.22</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.1</td>
#       <td>1.2</td>
#       <td>1.11</td>
#       <td>1.22</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.1</td>
#       <td>1.2</td>
#       <td>1.11</td>
#       <td>1.22</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>X</th>
#       <th>Y</th>
#     </tr>
#     <tr>
#       <th>row</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">0</th>
#       <th>One</th>
#       <td>1.10</td>
#       <td>1.20</td>
#     </tr>
#     <tr>
#       <th>Two</th>
#       <td>1.11</td>
#       <td>1.22</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">1</th>
#       <th>One</th>
#       <td>1.10</td>
#       <td>1.20</td>
#     </tr>
#     <tr>
#       <th>Two</th>
#       <td>1.11</td>
#       <td>1.22</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">2</th>
#       <th>One</th>
#       <td>1.10</td>
#       <td>1.20</td>
#     </tr>
#     <tr>
#       <th>Two</th>
#       <td>1.11</td>
#       <td>1.22</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;

# %%
display_side_by_side(df, df.stack(1))
# Out:
# /tmp/ipykernel_1364/4121828742.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   display_side_by_side(df, df.stack(1))
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="2" halign="left">One</th>
#       <th colspan="2" halign="left">Two</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>X</th>
#       <th>Y</th>
#       <th>X</th>
#       <th>Y</th>
#     </tr>
#     <tr>
#       <th>row</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.1</td>
#       <td>1.2</td>
#       <td>1.11</td>
#       <td>1.22</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.1</td>
#       <td>1.2</td>
#       <td>1.11</td>
#       <td>1.22</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.1</td>
#       <td>1.2</td>
#       <td>1.11</td>
#       <td>1.22</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>One</th>
#       <th>Two</th>
#     </tr>
#     <tr>
#       <th>row</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">0</th>
#       <th>X</th>
#       <td>1.1</td>
#       <td>1.11</td>
#     </tr>
#     <tr>
#       <th>Y</th>
#       <td>1.2</td>
#       <td>1.22</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">1</th>
#       <th>X</th>
#       <td>1.1</td>
#       <td>1.11</td>
#     </tr>
#     <tr>
#       <th>Y</th>
#       <td>1.2</td>
#       <td>1.22</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">2</th>
#       <th>X</th>
#       <td>1.1</td>
#       <td>1.11</td>
#     </tr>
#     <tr>
#       <th>Y</th>
#       <td>1.2</td>
#       <td>1.22</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;

# %%
df.index
# Out:
# Index([0, 1, 2], dtype='int64', name='row')

# %%
df.columns
# Out:
# MultiIndex([('One', 'X'),
#             ('One', 'Y'),
#             ('Two', 'X'),
#             ('Two', 'Y')],
#            )

# %%
df.stack(0).index
# Out:
# /tmp/ipykernel_1364/3155334174.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack(0).index
# MultiIndex([(0, 'One'),
#             (0, 'Two'),
#             (1, 'One'),
#             (1, 'Two'),
#             (2, 'One'),
#             (2, 'Two')],
#            names=['row', None])

# %%
df.stack(1).index
# Out:
# /tmp/ipykernel_1364/101924094.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack(1).index
# MultiIndex([(0, 'X'),
#             (0, 'Y'),
#             (1, 'X'),
#             (1, 'Y'),
#             (2, 'X'),
#             (2, 'Y')],
#            names=['row', None])

# %% [markdown]
# ## 단계별 데이터 변환 과정
# - 1단계: df.stack(0)
#     - → MultiIndex column의 level 0을 index로 이동
# - 2단계: df.reset_index(1)
#     - → 방금 추가된 index(level 1)을 다시 컬럼으로 이동
# ## 핵심 개념
# - stack = "열 → 행"
# - reset_index = "행 → 열 (일부 복구)"

# %%
df.stack(0).reset_index(1)
# Out:
# /tmp/ipykernel_1364/964097248.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack(0).reset_index(1)
#     level_1     X     Y
# row
# 0       One  1.10  1.20
# 0       Two  1.11  1.22
# 1       One  1.10  1.20
# 1       Two  1.11  1.22
# 2       One  1.10  1.20
# 2       Two  1.11  1.22

# %%
df = df.stack(0).reset_index(1)
df.columns = ["Sample", "All_X", "All_Y"]
df
# Out:
# /tmp/ipykernel_1364/3528973648.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df = df.stack(0).reset_index(1)
#     Sample  All_X  All_Y
# row
# 0      One   1.10   1.20
# 0      Two   1.11   1.22
# 1      One   1.10   1.20
# 1      Two   1.11   1.22
# 2      One   1.10   1.20
# 2      Two   1.11   1.22

# %% [markdown]
# ## 산술

# %%
cols = pd.MultiIndex.from_tuples(
    [(x, y) for x in ["A", "B", "C"] for y in ["O", "I"]]
)
cols
# Out:
# MultiIndex([('A', 'O'),
#             ('A', 'I'),
#             ('B', 'O'),
#             ('B', 'I'),
#             ('C', 'O'),
#             ('C', 'I')],
#            )

# %%
df = pd.DataFrame(np.random.randn(2, 6), index=["n", "m"], columns=cols)
df
# Out:
#           A                   B                   C
#           O         I         O         I         O         I
# n -0.062056  1.445763 -1.894813 -1.528168 -0.132705  0.738293
# m -1.808827 -0.112696  0.056427  0.779977 -1.262941 -0.897189

# %%
df.loc['m', ('B', 'O')]/df.loc['m', ('C', 'O')]
# Out:
# np.float64(-0.0446788467858005)

# %%
df2 = df.div(df["C"], level=1)
df2
# Out:
#           A                    B              C
#           O         I          O         I    O    I
# n  0.467625  1.958252  14.278422 -2.069867  1.0  1.0
# m  1.432234  0.125610  -0.044679 -0.869356  1.0  1.0

# %% [markdown]
# ### MultiIndex 슬라이싱
#
# `xs`와 `loc`를 활용하면 계층형 인덱스의 특정 수준만 골라낼 수 있습니다.

# %%
coords = [("AA", "one"), ("AA", "six"), ("BB", "one"), ("BB", "two"), ("BB", "six")]
index = pd.MultiIndex.from_tuples(coords)
df = pd.DataFrame([11, 22, 33, 44, 55], index, ["MyData"])
df
# Out:
#         MyData
# AA one      11
#    six      22
# BB one      33
#    two      44
#    six      55

# %%
df.index
# Out:
# MultiIndex([('AA', 'one'),
#             ('AA', 'six'),
#             ('BB', 'one'),
#             ('BB', 'two'),
#             ('BB', 'six')],
#            )

# %% [markdown]
# ## pandas에서 xs(cross section(단면, 횡단면)의 약자)의 의미
# ### MultiIndex에서의 역할
# - pandas에서는 MultiIndex 구조를
#     - → “여러 축으로 구성된 데이터”로 본다
# - xs()는
#     - → 특정 레벨 값을 기준으로
#     - → 데이터를 “슬라이스(단면 추출)”하는 함수이다

# %%
df
# Out:
#         MyData
# AA one      11
#    six      22
# BB one      33
#    two      44
#    six      55

# %%
df.xs("one", level=1)
# Out:
#     MyData
# AA      11
# BB      33

# %%
df.xs("six", level=1)
# Out:
#     MyData
# AA      22
# BB      55

# %%
df.xs("AA", level=0)
# Out:
#      MyData
# one      11
# six      22

# %%
df.xs("AA")
# Out:
#      MyData
# one      11
# six      22

# %%
xs_level0 = df.xs("BB", level=0, axis=0)
xs_level1 = df.xs("six", level=1, axis=0)
xs_level0, xs_level1
# Out:
# (     MyData
#  one      33
#  two      44
#  six      55,
#      MyData
#  AA      22
#  BB      55)

# %%
df
# Out:
#         MyData
# AA one      11
#    six      22
# BB one      33
#    two      44
#    six      55

# %%
display_side_by_side(xs_level0, xs_level1)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MyData</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>one</th>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>two</th>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>six</th>
#       <td>55</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MyData</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AA</th>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>BB</th>
#       <td>55</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;

# %% [markdown]
# ### 결측값 처리
#
# 뒤쪽 값으로 채우는 `bfill()` 예제입니다.

# %%
np.random.seed(0)
df = pd.DataFrame(
    np.random.randn(6, 1),
    index=pd.date_range("2013-08-01", periods=6, freq="B"),
    columns=list("A"),
)
df.loc[df.index[3], "A"] = np.nan
df
# Out:
#                    A
# 2013-08-01  1.764052
# 2013-08-02  0.400157
# 2013-08-05  0.978738
# 2013-08-06       NaN
# 2013-08-07  1.867558
# 2013-08-08 -0.977278

# %%
df.bfill()
# Out:
#                    A
# 2013-08-01  1.764052
# 2013-08-02  0.400157
# 2013-08-05  0.978738
# 2013-08-06  1.867558
# 2013-08-07  1.867558
# 2013-08-08 -0.977278

# %%
df.ffill()
# Out:
#                    A
# 2013-08-01  1.764052
# 2013-08-02  0.400157
# 2013-08-05  0.978738
# 2013-08-06  0.978738
# 2013-08-07  1.867558
# 2013-08-08 -0.977278

# %% [markdown]
# ### GroupBy + apply
#
# `agg`와 달리 `apply`는 각 그룹의 부분 DataFrame 자체를 받아서 여러 열을 함께 참조할 수 있습니다.

# %%
df = pd.DataFrame(
    {
        "animal": "cat dog cat fish dog cat cat".split(),
        "size": list("SSMMMLL"),
        "weight": [8, 10, 11, 1, 20, 12, 12],
        "adult": [False] * 5 + [True] * 2,
    }
)
df
# Out:
#   animal size  weight  adult
# 0    cat    S       8  False
# 1    dog    S      10  False
# 2    cat    M      11  False
# 3   fish    M       1  False
# 4    dog    M      20  False
# 5    cat    L      12   True
# 6    cat    L      12   True

# %%
# List the size of the animals with the highest weight.
df.groupby("animal").apply(lambda subf: subf["size"][subf["weight"].idxmax()])
# Out:
# /tmp/ipykernel_1364/3491427077.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby("animal").apply(lambda subf: subf["size"][subf["weight"].idxmax()])
# animal
# cat     L
# dog     M
# fish    M
# dtype: object

# %%
df.loc[df.groupby("animal")["weight"].idxmax(), ["animal", "size"]]
# Out:
#   animal size
# 5    cat    L
# 4    dog    M
# 3   fish    M

# %%
df.loc[df.groupby("animal")["weight"].idxmax(), ["animal", "size"]].set_index("animal")
# Out:
#        size
# animal
# cat       L
# dog       M
# fish      M

# %%
gb = df.groupby("animal")
gb.get_group("cat")
# Out:
#   animal size  weight  adult
# 0    cat    S       8  False
# 2    cat    M      11  False
# 5    cat    L      12   True
# 6    cat    L      12   True

# %%
gb.get_group("dog")
# Out:
#   animal size  weight  adult
# 1    dog    S      10  False
# 4    dog    M      20  False

# %%
gb.get_group("fish")
# Out:
#   animal size  weight  adult
# 3   fish    M       1  False

# %% [markdown]
# ### 종료
